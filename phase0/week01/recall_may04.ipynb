# %%
number = 1
print(type(number))
# Out:
# <class 'int'>

# %%
floater = 1.2
print(type(floater))
# Out:
# <class 'float'>

# %%
day = 'Monday'
print(type(day))
new_day = day.upper()
print(new_day)
line = 'The amount is $52'
new_line = line.split()
print(new_line)
new_day
# Out:
# <class 'str'>
# MONDAY

# %%
test = 30

# %%
week = ['monday', 'tuesday', 'wednesday', 'thursday']
week.append('Friday')
print(week)
# Out:
# ['monday', 'tuesday', 'wednesday', 'thursday', 'Friday']

# %%
# 1. Use .strip() on a string with spaces
new_string = ' Today is a good day! '
ayo = new_string.strip()
print(ayo)
# Out:
# Today is a good day!

# %%
# 2. Use .split() on a sentence
line = 'The amount is $52'
new_line = line.split()
print(new_line)
# Out:
# ['The', 'amount', 'is', '$52']

# %%
# 3. Use an f-string to print your name and age
name = 'Chiranjay Verma'
age = 30
print(f"My name is {name} and I am {age} years old")
# Out:
# My name is Chiranjay Verma and I am 30 years old

# %%
week = ['monday', 'tuesday', 'wednesday', 'thursday']
week.append('friday')
new_week = ['Saturday', 'Sunday']
week.extend(new_week)
print(week)
# Out:
# ['monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'Saturday', 'Sunday']

# %%
phone_book= {
    'name': 'CJ',
    'age': 30,
    'day': 'Monday'
}
print(phone_book['red'])
print(phone_book.get('orange'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[96], line 6
#       1 phone_book= {
#       2     'name': 'CJ',
#       3     'age': 30,
#       4     'day': 'Monday'
#       5 }
# ----> 6 print(phone_book['red'])
#       7 print(phone_book.get('orange'))
#
# KeyError: 'red'
