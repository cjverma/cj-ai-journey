# %%
# Functions
def my_function():
  print("Hello from a function")
my_function()
# Out:
# Hello from a function

# %%
def fahrenheit_to_celsius(fahrenheit):
  fahrenheit = int(input("What is your temperature?"))
    return (fahrenheit - 32) * 5 / 9
    break

fahrenheit_to_celsius(int(input("What is your temperature?")))

# %%
print(10 / 2)
print(type(10 / 2))
# Out:
# 5.0
# <class 'float'>

# %%
a, b, *c = (1,2,3,4,5)
print (c)
# Out:
# [3, 4, 5]

# %%
phone_book = {
    "person_a": {"name": "Chiranjay Verma",
    "phone": "+1-519-574-4155",
    "email":"chiranjay.verma@gmail.com" },
    "person_b": {"name": "Chiranjay1 Verma",
    "phone": "+1-519-574-4156",
    "email": "chiranjay.verma1@gmail.com" },
    "person_c": {"name": "Chiranjay2 Verma",
    "phone": "+1-519-574-4157",
    "email": "chiranjay.verma2@gmail.com" }
}
#for keys, values in phone_book["person_a"]:
 #   print(key, value)
print(phone_book["person_a"]["email"])
print(phone_book["person_b"]["email"])
# Out:
# chiranjay.verma@gmail.com
# chiranjay.verma1@gmail.com

# %%
# Assistant
# Explanation of nested dictionary access:
# Think of it as two separate steps happening left to right:
# 1. `phone_book["person_b"]` → gives you the nested dictionary
# 2. `["email"]` → goes into that dictionary and gets the email

# ---

# Commit message for version control:
# You've now covered dictionaries properly. Let's do a quick commit before moving on.
git add . && git commit -m 'feat: sun march 22 — nested dict loop, contact book'
# Out:
#   Cell In[115], line 11
#     git add . && git commit -m 'feat: sun march 22 — nested dict loop, contact book'
#         ^
# SyntaxError: invalid syntax
