# %%
x = 5
if x == 5 and x!=6:
    print("God is great")
elif x== 4:
    print("God is not great")
else:
    print("I don't know what's happening")
# Out:
# God is great

# %%
#Exercise 1: write code that prints whether a number is positive, negative, or zero.

x = 5
if x <0:
    print("It's a negative number!")
elif x == 0:
    print("It's zero")
else: print(" It's a positive number")
# Out:
#  It's a positive number

# %%
#Exercise 2: Write code that checks if a number is divisible by both 3 and 5.
x = 15
if x%3 == 0 and x%5 == 0:
    print("Number is divisible by both 3 and 5")
else: print("Number is not divisible by both 3 and 5")
# Out:
# Number is divisible by both 3 and 5
