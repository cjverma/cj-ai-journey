# %%
name = 'CJ'

# %%
print(name)
print(type(name))
# Out:
# CJ
# <class 'str'>

# %%
age = 30
print(age)
# Out:
# 30

# %%
print('My name is',name)
# Out:
# My name is CJ

# %%
print('My name is', name)
# Out:
# My name is CJ

# %%
x = 10
y = 20
print(x>y);
print(x-y)
# Out:
# False
# -10
