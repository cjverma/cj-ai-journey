# %%
#data types

# %%
#Integer
#String
#Tuple(ordered immutable list)
#list
#set(unique unordered values)
#dictionary
#boolean
#float

# %%
a = 3
b = 'abc'
c = (1,2,3)
d = [a,b,c]
e = {1,2,3,4,5}
f = { 'age': 30, 'name': 'Chiranjay'}
g = True
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
print(type(f))
print(type(g))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'tuple'>
# <class 'list'>
# <class 'set'>
# <class 'dict'>
# <class 'bool'>

# %%
name = " Chiranjay Verma"
upper_case = name.upper()
lower_case = name.lower()
print(lower_case)
print(upper_case)
print(name.strip())
x = name.replace("Verma", "V")
print(x)
print(name[1]) # there's a space at 0 number
print(name[-4]) # there's a space at 0 number
print(name[-1:2])
print(len(name))
# Out:
#   Cell In[78], line 13
#     print(name.split(" ")
#                          ^
# SyntaxError: incomplete input
